# %% [markdown]
# <a href="https://colab.research.google.com/github/adrian-cadena/Lab1-Coursera-PracticaMarkdown/blob/main/Practice_Markdown_withcolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica de Markdown con Jupyter en Colab
# Acontinuación se escribira una porcion de código que imprimira el hola mundo.

# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# # Imprimir "Hola mundo en Colab" y subirlo a un repositorio de Github
# * Abrir colab
# * Escribir en lenguaje Python "Hola mundo" con la funcion "print"
# * En la pestaña de "Archivo" seleccionar la opción "Guardar una copia en Github"
# * Conectar Colab con Github y seguir los pasos
# * Seleccionar el repositorio donde se desea publicar el archivo Colab
